# %%
import pandas as pd
import newspaper
import re
import time
import requests
import json
import os
from datetime import datetime
from urllib.parse import quote, urlparse
import logging

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("article_search.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

class ArticleFinder:
    def __init__(self, api_key, search_engine_id, output_dir="downloaded_articles"):
        """
        Initialize the ArticleFinder with required credentials and settings
        
        Args:
            api_key: Google API key
            search_engine_id: Google Custom Search Engine ID
            output_dir: Directory to save HTML files
        """
        self.api_key = api_key
        self.search_engine_id = search_engine_id
        self.output_dir = output_dir
        
        # Create output directory if it doesn't exist
        os.makedirs(output_dir, exist_ok=True)
        logger.info(f"HTML files will be saved to {output_dir}")
        
        # Track API usage to avoid exceeding limits
        self.search_count = 0
        self.results = []
    
    def extract_slug(self, url):
        """Extract the article slug from RSS feed URLs"""
        # Try multiple patterns to extract slugs from different URL formats

        # Pattern for specific sections (newstopstories, techtopstories, etc.)
        match = re.search(r'usatoday-(\w+)~(.*?)(?:/|$)', url)
        if match:
            slug = match.group(2)
            search_term = slug.replace('-', ' ')
            return slug, search_term

        # Pattern for nation-topstories format
        match = re.search(r'usatodaycom(\w+)-topstories~(.*?)(?:/|$)', url)
        if match:
            slug = match.group(2)
            search_term = slug.replace('-', ' ')
            return slug, search_term

        # Last resort: Extract the last segment of the URL path
        parts = url.rstrip('/').split('/')
        if parts and len(parts) > 0:
            last_segment = parts[-1]
            # Check if it looks like a slug (contains dashes)
            if '-' in last_segment and not last_segment.startswith('~'):
                search_term = last_segment.replace('-', ' ')
                return last_segment, search_term

        return None, None
    
    def dedupe_by_slug(urls, extract_slug_func):
        seen_slugs = set()
        unique_urls = []

        for url in urls:
            slug, _ = extract_slug_func(url)
            if slug and slug not in seen_slugs:
                seen_slugs.add(slug)
                unique_urls.append(url)

        return unique_urls

    def search_for_article(self, search_term, site="usatoday.com"):
        """
        Search for an article using Google's Custom Search API
        
        Args:
            search_term: The term to search for
            site: The site to restrict search to
            
        Returns:
            The URL of the first search result, or None if no results
        """
        # Properly format the search query with site restriction
        query = f"site:{site} {search_term}"
        logger.info(f"Searching for: {query}")
        
        # Track API usage (Google CSE has limits)
        self.search_count += 1
        if self.search_count % 10 == 0:
            logger.info(f"Search API count: {self.search_count}")
        
        # Custom Search API URL
        search_url = "https://www.googleapis.com/customsearch/v1"
        
        # Parameters for the API request
        params = {
            "key": self.api_key,
            "cx": self.search_engine_id,
            "q": query,
            "num": 5  # Request 5 results
        }
        
        try:
            # Make the API request with proper error handling
            response = requests.get(search_url, params=params)
            
            if response.status_code == 200:
                data = response.json()
                
                # Check if we have search items
                if "items" in data and len(data["items"]) > 0:
                    # Get the first result URL
                    result_url = data["items"][0]["link"]
                    result_title = data["items"][0]["title"]
                    logger.info(f"Found article: {result_title} at {result_url}")
                    return result_url, result_title
                else:
                    logger.warning(f"No search results found for '{query}'")
                    if "searchInformation" in data:
                        logger.info(f"Total results: {data['searchInformation'].get('totalResults', 0)}")
            else:
                # Detailed error logging
                logger.error(f"Search API error: {response.status_code}")
                logger.error(f"Error details: {response.text}")
                
                # Handle specific error codes
                if response.status_code == 403:
                    logger.error("Error 403: API quota exceeded or invalid credentials")
                elif response.status_code == 429:
                    logger.warning("Error 429: Rate limit exceeded, waiting before retry")
                    time.sleep(10)  # Wait longer for rate limit
                    
        except Exception as e:
            logger.error(f"Search API exception: {str(e)}")
        
        return None, None
    
    def download_and_parse_article(self, url):
        """
        Download and parse an article using newspaper3k
        
        Args:
            url: URL of the article to download
            
        Returns:
            Dictionary with article data and success status
        """
        logger.info(f"Downloading article from: {url}")
        
        try:
            article = newspaper.Article(url)
            article.download()
            
            # Save the HTML content
            html_content = article.html
            
            # Create a filename based on the URL
            parsed_url = urlparse(url)
            domain = parsed_url.netloc.replace(".", "_")
            path = parsed_url.path.strip("/").replace("/", "_")
            if not path:
                path = "index"
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"{domain}_{path}_{timestamp}.html"
            filepath = os.path.join(self.output_dir, filename)
            
            # Save the HTML
            with open(filepath, "w", encoding="utf-8") as f:
                f.write(html_content)
            
            # Parse the article
            article.parse()
            
            return {
                "url": url,
                "title": article.title,
                "text": article.text[:500] + "..." if len(article.text) > 500 else article.text,
                "publish_date": str(article.publish_date),
                "authors": article.authors,
                "html_saved_path": filepath,
                "html_size": len(html_content),
                "text_size": len(article.text),
                "success": True
            }
            
        except Exception as e:
            logger.error(f"Error downloading/parsing {url}: {str(e)}")
            return {
                "url": url,
                "error": str(e),
                "success": False
            }
    
    def process_rss_urls(self, urls, max_urls=None, results_file="article_results.jsonl"):
        """
        Process a list of RSS feed URLs to find and download the actual articles

        Args:
            urls: List of RSS feed URLs
            max_urls: Maximum number of URLs to process (None for all)
            results_file: JSONL file to save results to incrementally

        Returns:
            Pandas DataFrame with article data
        """
        self.results = []
        total_urls = len(urls)

        if max_urls:
            urls = urls[:max_urls]
            logger.info(f"Processing {len(urls)} of {total_urls} URLs")
        else:
            logger.info(f"Processing all {total_urls} URLs")

        # Create or truncate the JSONL file at the start
        with open(results_file, 'w') as f:
            f.write('')  # Just create/truncate the file

        for i, url in enumerate(urls):
            logger.info(f"Processing {i+1}/{len(urls)}: {url}")

            # Extract the slug
            slug, search_term = self.extract_slug(url)
            if not slug:
                logger.warning(f"Could not extract slug from URL: {url}")

                # Create failed entry
                result = {
                    "original_rss_url": url,
                    "slug": None,
                    "search_term": None,
                    "found_url": None,
                    "found_title": None,
                    "success": False,
                    "error": "Could not extract slug",
                    "timestamp": datetime.now().isoformat()
                }

                # Append to JSONL file
                self._append_to_jsonl(result, results_file)

                # Also keep in memory
                self.results.append(result)
                continue

            logger.info(f"Extracted slug: {slug}")
            logger.info(f"Search term: {search_term}")

            # Search for the article - just one simple search approach
            found_url, found_title = self.search_for_article(search_term)

            if not found_url:
                logger.warning(f"No article found for slug: {slug}")
                
                # Create failed entry
                result = {
                    "original_rss_url": url,
                    "slug": slug,
                    "search_term": search_term,
                    "found_url": None,
                    "found_title": None,
                    "success": False,
                    "error": "No article found",
                    "timestamp": datetime.now().isoformat()
                }
                
                # Append to JSONL file
                self._append_to_jsonl(result, results_file)
                
                # Also keep in memory
                self.results.append(result)
                continue

            # Download and parse the article
            article_data = self.download_and_parse_article(found_url)

            # Add original URL info and search results
            result = {
                "original_rss_url": url,
                "slug": slug,
                "search_term": search_term,
                "found_url": found_url,
                "found_title": found_title,
                "timestamp": datetime.now().isoformat()
            }
            result.update(article_data)

            # Append to JSONL file
            self._append_to_jsonl(result, results_file)

            # Also keep in memory
            self.results.append(result)

            # Be nice to servers
            time.sleep(2)

        # Create DataFrame from final results
        df = pd.DataFrame(self.results)

        # Save final results as CSV as well
        self.save_results("article_results.csv", df)

        return df

    def _append_to_jsonl(self, result, jsonl_file):
        """
        Append a single result to a JSONL file

        Args:
            result: Result dictionary to append
            jsonl_file: Path to JSONL file
        """
        # Create a copy of the result to avoid modifying the original
        result_copy = result.copy()

        # If the result contains HTML content, truncate it to save space
        if "html_content" in result_copy:
            result_copy["html_content"] = f"[HTML content truncated, {len(result_copy['html_content'])} bytes]"

        # If the result contains article text, truncate it if it's too long
        if "text" in result_copy and len(result_copy["text"]) > 1000:
            result_copy["text"] = result_copy["text"][:1000] + "..."

        # Append to the JSONL file
        with open(jsonl_file, 'a', encoding='utf-8') as f:
            f.write(json.dumps(result_copy) + '\n')

        logger.debug(f"Appended result for {result_copy.get('slug', 'unknown')} to {jsonl_file}")
    
    def save_results(self, filename="article_results.csv", df=None):
        """
        Save results to a CSV file using append mode

        Args:
            filename: Name of the CSV file
            df: DataFrame to save (uses self.results if None)

        Returns:
            The DataFrame that was saved
        """
        if df is None:
            df = pd.DataFrame(self.results)

        # Check if file exists to determine if header should be written
        file_exists = os.path.isfile(filename)

        # Append to file if it exists, create new file if it doesn't
        df.to_csv(filename, mode='a', header=not file_exists, index=False)

        logger.info(f"Results {'appended to' if file_exists else 'saved to'} {filename}")

        return df

# %%
# Example usage
if __name__ == "__main__":
    API_KEY = ""
    SEARCH_ENGINE_ID = ""

    with open('usat_urls.json', 'r', encoding='utf-8') as f:
        raw_urls = json.load(f)
    
    ## Already Processed
    # Path to your log file
    log_path = "article_search.log"

    # Read and extract rssfeeds URLs
    with open(log_path, "r") as f:
        log_data = f.read()

    # Regex pattern for rssfeeds URLs
    pattern = r"http[s]?://rssfeeds[^\s]+"
    rssfeed_urls = re.findall(pattern, log_data)

    rssfeed_urls = set(rssfeed_urls)
    unprocessed_urls = list(set(raw_urls) - rssfeed_urls)
    
    # Deduplicate using slugs
    finder = ArticleFinder(API_KEY, SEARCH_ENGINE_ID)
    seen_slugs = set()
    deduped_urls = []

    for url in unprocessed_urls:
        slug, _ = finder.extract_slug(url)
        if slug and slug not in seen_slugs:
            seen_slugs.add(slug)
            deduped_urls.append(url)

    # Take the desired slice
    urls = deduped_urls
    print(len(urls))

    # Now process
    df = finder.process_rss_urls(urls)

    print("\nResults Summary:")
    print(f"Total URLs processed: {len(df)}")
    print(f"Successfully retrieved: {df['success'].sum()}")
    print(f"Failed: {len(df) - df['success'].sum()}")
        
    # Show the DataFrame
    print("\nDataFrame Preview:")
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 1000)
    print(df[['slug', 'found_title', 'found_url', 'success', 'html_saved_path']].head())
# Out:
# 2025-04-07 18:39:47,385 - INFO - HTML files will be saved to downloaded_articles
# 2025-04-07 18:39:47,392 - INFO - Processing all 1266 URLs
# 2025-04-07 18:39:47,508 - INFO - Processing 1/1266: http://rssfeeds.usatoday.com/~/723790304/0/usatodaycomnation-topstories~AP-Top-Stories-January-A/
# 2025-04-07 18:39:47,509 - INFO - Extracted slug: AP-Top-Stories-January-A
# 2025-04-07 18:39:47,509 - INFO - Search term: AP Top Stories January A
# 2025-04-07 18:39:47,509 - INFO - Searching for: site:usatoday.com AP Top Stories January A
# 1266
# 2025-04-07 18:39:48,316 - INFO - Found article: AP Top Stories January 25 A at https://www.usatoday.com/videos/news/nation/2024/01/25/ap-top-stories-january-25-a/72349433007/
# 2025-04-07 18:39:48,319 - INFO - Downloading article from: https://www.usatoday.com/videos/news/nation/2024/01/25/ap-top-stories-january-25-a/72349433007/
# 2025-04-07 18:39:49,602 - ERROR - Error downloading/parsing https://www.usatoday.com/videos/news/nation/2024/01/25/ap-top-stories-january-25-a/72349433007/: Article `download()` failed with 404 Client Error: OK for url: https://www.usatoday.com/videos/news/nation/2024/01/25/ap-top-stories-january-25-a/72349433007/ on URL https://www.usatoday.com/videos/news/nation/2024/01/25/ap-top-stories-january-25-a/72349433007/
# 2025-04-07 18:39:51,610 - INFO - Processing 2/1266: http://rssfeeds.usatoday.com/~/724774097/0/usatodaycomnation-topstories~Today-in-History-for-January-th/
# 2025-04-07 18:39:51,612 - INFO - Extracted slug: Today-in-History-for-January-th
# 2025-04-07 18:39:51,613 - INFO - Search term: Today in History for January th
# 2025-04-07 18:39:51,614 - INFO - Searching for: site:usatoday.com Today in History for January th
# 2025-04-07 18:39:52,144 - INFO - Found article: Today in History for January 11th at https://www.usatoday.com/videos/news/nation/2022/01/11/today-history-january-11-th/9165419002/
# 2025-04-07 18:39:52,146 - INFO - Downloading article from: https://www.usatoday.com/videos/news/nation/2022/01/11/today-history-january-11-th/9165419002/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 40
#      37 print(len(urls))
#      39 # Now process
# ---> 40 df = finder.process_rss_urls(urls)
#      42 print("\nResults Summary:")
#      43 print(f"Total URLs processed: {len(df)}")
#
# Cell In[1], line 289, in ArticleFinder.process_rss_urls(self, urls, max_urls, results_file)
#     286     continue
#     288 # Download and parse the article
# --> 289 article_data = self.download_and_parse_article(found_url)
#     291 # Add original URL info and search results
#     292 result = {
#     293     "original_rss_url": url,
#     294     "slug": slug,
#    (...)
#     298     "timestamp": datetime.now().isoformat()
#     299 }
#
# Cell In[1], line 166, in ArticleFinder.download_and_parse_article(self, url)
#     164 try:
#     165     article = newspaper.Article(url)
# --> 166     article.download()
#     168     # Save the HTML content
#     169     html_content = article.html
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/newspaper/article.py:170, in Article.download(self, input_html, title, recursion_counter)
#     168 if input_html is None:
#     169     try:
# --> 170         html = network.get_html_2XX_only(self.url, self.config)
#     171     except requests.exceptions.RequestException as e:
#     172         self.download_state = ArticleDownloadState.FAILED_RESPONSE
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/newspaper/network.py:62, in get_html_2XX_only(url, config, response)
#      59 if response is not None:
#      60     return _get_html_from_response(response)
# ---> 62 response = requests.get(
#      63     url=url, **get_request_kwargs(timeout, useragent, proxies, headers))
#      65 html = _get_html_from_response(response)
#      67 if config.http_success_only:
#      68     # fail if HTTP sends a non 2XX response
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/urllib3/connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#     730 response_conn = conn if not release_conn else None
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/urllib3/connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402 # Trigger any extra validation we need to do.
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     407     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/urllib3/connectionpool.py:1061, in HTTPSConnectionPool._validate_conn(self, conn)
#    1059 # Force connect early to allow us to validate the connection.
#    1060 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1061     conn.connect()
#    1063 if not conn.is_verified:
#    1064     warnings.warn(
#    1065         (
#    1066             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1071         InsecureRequestWarning,
#    1072     )
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/urllib3/connection.py:419, in HTTPSConnection.connect(self)
#     410 if (
#     411     not self.ca_certs
#     412     and not self.ca_cert_dir
#    (...)
#     415     and hasattr(context, "load_default_certs")
#     416 ):
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#     435 if (
#     436     default_ssl_context
#     437     and self.ssl_version is None
#     438     and hasattr(self.sock, "version")
#     439     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     440 ):  # Defensive:
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/urllib3/util/ssl_.py:458, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     446     warnings.warn(
#     447         "An HTTPS request has been made, but the SNI (Server Name "
#     448         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     454         SNIMissingWarning,
#     455     )
#     457 if send_sni:
# --> 458     ssl_sock = _ssl_wrap_socket_impl(
#     459         sock, context, tls_in_tls, server_hostname=server_hostname
#     460     )
#     461 else:
#     462     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages/urllib3/util/ssl_.py:502, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     499     return SSLTransport(sock, ssl_context, server_hostname)
#     501 if server_hostname:
# --> 502     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     503 else:
#     504     return ssl_context.wrap_socket(sock)
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/ssl.py:1104, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1101             if timeout == 0.0:
#    1102                 # non-blocking
#    1103                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1104             self.do_handshake()
#    1105 except:
#    1106     try:
#
# File ~/opt/anaconda3/envs/py311ds/lib/python3.11/ssl.py:1382, in SSLSocket.do_handshake(self, block)
#    1380     if timeout == 0.0 and block:
#    1381         self.settimeout(None)
# -> 1382     self._sslobj.do_handshake()
#    1383 finally:
#    1384     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
with open('usat_urls.json', 'r', encoding='utf-8') as f:
        raw_urls = json.load(f)
    

log_path = "article_search.log"

with open(log_path, "r") as f:
    log_data = f.read()

pattern = r"http[s]?://rssfeeds[^\s]+"
rssfeed_urls = re.findall(pattern, log_data)

rssfeed_urls = list(set(rssfeed_urls))
unprocessed_urls =  list(set(raw_urls) - set(rssfeed_urls))
    
finder = ArticleFinder(API_KEY, SEARCH_ENGINE_ID)
seen_slugs = set()
deduped_urls = []

for url in unprocessed_urls:
    slug, _ = finder.extract_slug(url)
    if slug and slug not in seen_slugs:
        seen_slugs.add(slug)
        deduped_urls.append(url)

len(deduped_urls)
# Out:
# 2025-04-04 10:14:53,858 - INFO - HTML files will be saved to downloaded_articles
# 22166

# %%
API_KEY = "AIzaSyBaC0E3rPFtQlfccgJJetBLB-abFMStqaA"
SEARCH_ENGINE_ID = "e3cd371a06a394127"

with open('usat_urls.json', 'r', encoding='utf-8') as f:
        raw_urls = json.load(f)

# Deduplicate using slugs
parser =  ArticleFinder(API_KEY, SEARCH_ENGINE_ID)

seen_slugs = set()
deduped_urls = []

for url in raw_urls:
    slug, _ = parser.extract_slug(url)
    if slug and slug not in seen_slugs:
        seen_slugs.add(slug)
        deduped_urls.append(url)
len(deduped_urls)
# Out:
# 2025-04-02 11:09:04,377 - INFO - HTML files will be saved to downloaded_articles
# 38062

# %%
import os
import csv
import logging
from typing import List, Dict
from tqdm import tqdm
import pandas as pd
from bs4 import BeautifulSoup

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s: %(message)s',
    handlers=[
        logging.FileHandler('usa_today_extraction.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

def extract_metadata_from_filename(filename: str) -> dict:
    """
    Extract metadata from the filename
    
    Args:
        filename (str): Name of the HTML file
    
    Returns:
        dict: Extracted metadata from filename
    """
    # Remove file extension
    name_without_ext = os.path.splitext(filename)[0]
    
    # Split the filename by underscores
    parts = name_without_ext.split('_')
    
    # Try to extract meaningful parts
    metadata = {
        'domain': parts[0] if len(parts) > 0 else '',
        'source': ' '.join(parts[1:3]) if len(parts) > 2 else '',
        'date_in_filename': parts[-2] if len(parts) > 1 else '',
        'timestamp': parts[-1] if len(parts) > 0 else ''
    }
    
    return metadata

def extract_text_from_html(html_path: str) -> dict:
    """
    Extract text and metadata from an HTML file
    
    Args:
        html_path (str): Path to the HTML file
    
    Returns:
        Dict: Extracted information
    """
    try:
        # Read the HTML file
        with open(html_path, 'r', encoding='utf-8') as file:
            html_content = file.read()
        
        # Parse with BeautifulSoup
        soup = BeautifulSoup(html_content, 'html.parser')
        
        # Extract filename metadata
        filename = os.path.basename(html_path)
        filename_metadata = extract_metadata_from_filename(filename)
        
        # Try to extract text from various elements
        text_candidates = []
        
        # Try different text extraction methods
        if soup.body:
            # Extract text from paragraphs
            paragraphs = soup.find_all(['p', 'div'])
            text_candidates = [p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True)]
        
        # Combine text candidates
        full_text = ' '.join(text_candidates)
        
        # Get title from title tag or first heading
        title = soup.title.string if soup.title else (soup.find(['h1', 'h2']) or {}).get_text(strip=True) or ''
        
        # Look for any potential meta tags
        meta_description = ''
        meta_tags = soup.find_all('meta')
        for tag in meta_tags:
            if tag.get('name', '').lower() in ['description', 'og:description']:
                meta_description = tag.get('content', '')
                break
        
        return {
            'filename': filename,
            'full_text': full_text,
            'title': title,
            'meta_description': meta_description,
            'domain': filename_metadata.get('domain', ''),
            'source': filename_metadata.get('source', ''),
            'date_in_filename': filename_metadata.get('date_in_filename', ''),
            'timestamp': filename_metadata.get('timestamp', ''),
            'file_path': html_path
        }
    except Exception as e:
        logger.error(f"Error processing {html_path}: {e}")
        return {
            'filename': os.path.basename(html_path),
            'error': str(e)
        }

def extract_articles_to_csv(folder_path: str, output_csv: str) -> None:
    """
    Extract information from all HTML files in a folder and save to CSV
    
    Args:
        folder_path (str): Path to the folder containing HTML files
        output_csv (str): Path to save the output CSV file
    """
    # Get all HTML files in the folder
    html_files = [
        os.path.join(folder_path, f) 
        for f in os.listdir(folder_path) 
        if f.endswith('.html')
    ]
    
    logger.info(f"Found {len(html_files)} HTML files to process")
    
    # Extract article info with progress bar
    articles_data = []
    skipped_files = 0
    
    for file in tqdm(html_files, desc="Extracting Articles", unit="file"):
        article = extract_text_from_html(file)
        
        # Filter out entries with errors or empty text
        if 'error' not in article and article.get('full_text', '').strip():
            articles_data.append(article)
        else:
            skipped_files += 1
    
    # Convert to DataFrame for easy CSV export
    df = pd.DataFrame(articles_data)
    
    # Save to CSV
    df.to_csv(output_csv, index=False, quoting=csv.QUOTE_ALL, encoding='utf-8')
    
    # Log summary
    logger.info(f"Extracted {len(articles_data)} articles to {output_csv}")
    logger.info(f"Skipped {skipped_files} files due to errors or empty content")

# Example usage
if __name__ == "__main__":
    # Replace these with your actual paths
    input_folder = "downloaded_articles/"
    output_file = "usa_today_articles.csv"
    
    extract_articles_to_csv(input_folder, output_file)
# Out:
# 2025-04-07 19:45:50,493 - INFO - Found 24624 HTML files to process
# Extracting Articles:   1%|                | 176/24624 [00:02<05:07, 79.60file/s]2025-04-07 19:45:53,017 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_09_28_international-space-station-gets-new-commander_10454984002_20250331_200013.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:45:53,029 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_04_heavy-rains-and-floods-prompt-sydney-evacuations_7801839001_20250331_143633.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   1%|▏               | 195/24624 [00:02<04:47, 84.93file/s]2025-04-07 19:45:53,299 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_10_27_canine-cafe-offers-75-tasting-menu-pampered-pups_10612869002_20250401_193143.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   1%|▏               | 227/24624 [00:02<04:16, 95.00file/s]2025-04-07 19:45:53,752 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_10846550002_20250407_130624.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   1%|▏               | 256/24624 [00:03<05:09, 78.63file/s]2025-04-07 19:45:53,994 - ERROR - Error processing downloaded_articles/admeter_usatoday_com_videos_news_politics_2023_08_01_trump-indicted-conduct-before-during-and-after-his-presidency_12308734002_20250405_124416.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   1%|▏               | 355/24624 [00:04<04:54, 82.42file/s]2025-04-07 19:45:55,272 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_22_thaksin-shinawatra-returns-thailand-exile_8367409001_20250403_160510.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   2%|▎               | 397/24624 [00:04<04:19, 93.38file/s]2025-04-07 19:45:55,779 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_04_26_xi-calls-talks-between-russia-and-ukraine_11744095002_20250402_122610.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:45:55,802 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_04_ap-top-stories-august-4-p_37307929_20250331_190513.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   2%|▎               | 418/24624 [00:05<04:23, 91.86file/s]2025-04-07 19:45:56,265 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_2023_08_14_police-raid-kansas-newspaper-publisher-calls-gestapo-tactics_8351597001_20250403_154006.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:45:56,266 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_29_west-point-time-capsule-yields-no-bombshells-just-dust_8379909001_20250403_164555.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   2%|▎               | 453/24624 [00:05<05:56, 67.78file/s]2025-04-07 19:45:56,684 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_08_12_police-rushdie-undergoes-surgery-after-attack_10314198002_20250331_181742.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   2%|▎               | 465/24624 [00:05<05:06, 78.70file/s]/var/folders/2p/6m62flgx7677h842nfsgzgvh0000gn/T/ipykernel_1053/816678086.py:62: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(html_content, 'html.parser')
# 2025-04-07 19:45:56,889 - ERROR - Error processing downloaded_articles/www_usatoday_com_news-sitemap.xml_20250403_153119.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   2%|▎               | 503/24624 [00:06<05:26, 73.87file/s]2025-04-07 19:45:57,376 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_04_10_justin-jones-reinstated-tennesee-house_11637789002_20250402_111151.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   2%|▎               | 532/24624 [00:06<04:44, 84.68file/s]2025-04-07 19:45:57,919 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_10_24_only-ap-new-fed-prisons-head-open-flaws_10592712002_20250401_191553.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   2%|▎               | 541/24624 [00:07<08:28, 47.38file/s]2025-04-07 19:45:58,059 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_04_iaea-report-due-fukushima-water-plan_12205663002_20250403_113857.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   2%|▎               | 552/24624 [00:07<06:55, 57.95file/s]2025-04-07 19:45:58,166 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_03_30_biggest-dinosaur-ever-show-uk_11568186002_20250407_130013.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   2%|▍               | 604/24624 [00:07<04:39, 85.79file/s]2025-04-07 19:45:58,725 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_12_thousands-flee-sudan-conflict-chad_12243684002_20250403_121735.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   3%|▍               | 635/24624 [00:08<04:35, 87.09file/s]2025-04-07 19:45:59,006 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_04_29_al-sharpton-spike-lee-pay-tribute-harry-belafonte_11767075002_20250402_124414.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   3%|▍               | 666/24624 [00:08<04:29, 88.93file/s]2025-04-07 19:45:59,414 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_01_12_mortar-fire-frontline-ukraine_11037673002_20250407_123614.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   3%|▍               | 677/24624 [00:08<04:16, 93.37file/s]2025-04-07 19:45:59,469 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_01_11_today-history-january-11-th_9165419002_20250405_133025.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   3%|▍               | 716/24624 [00:09<07:41, 51.77file/s]2025-04-07 19:46:00,283 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_22_police-raid-leaves-18-dead-rio-favela_10130078002_20250331_165243.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   3%|▌               | 788/24624 [00:10<04:36, 86.16file/s]2025-04-07 19:46:01,038 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_politics_2023_07_28_joe-biden-slams-tuberville-over-outrageous-military-promotion-holds_12297624002_20250403_134542.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   3%|▌               | 809/24624 [00:10<04:42, 84.43file/s]2025-04-07 19:46:01,330 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_11916771002_20250407_130552.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   3%|▌               | 821/24624 [00:10<04:18, 92.18file/s]2025-04-07 19:46:01,414 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_12173204002_20250403_110951.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   3%|▌               | 845/24624 [00:10<04:03, 97.48file/s]2025-04-07 19:46:01,618 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_2022_08_09_severe-flooding-colorado-turns-70-underpass-river_10279209002_20250331_174350.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   4%|▌               | 875/24624 [00:11<04:22, 90.41file/s]2025-04-07 19:46:01,968 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_7860949001_20250331_190737.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:02,022 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_12_drought-leaves-iraqi-farmlands-barren_10038845002_20250331_153241.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   4%|▌               | 886/24624 [00:11<04:11, 94.36file/s]2025-04-07 19:46:02,154 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_08_10_pelosi-we-not-allow-china-isolate-taiwan_10292646002_20250331_175052.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   4%|▌               | 907/24624 [00:11<04:01, 98.20file/s]2025-04-07 19:46:02,856 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_07_today-history-august-8th_37357341_20250331_182318.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   4%|▋               | 988/24624 [00:12<04:44, 83.23file/s]2025-04-07 19:46:03,667 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_12214072002_20250403_114550.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   4%|▋              | 1087/24624 [00:13<04:30, 87.10file/s]2025-04-07 19:46:04,876 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_13_quirky-tours-draw-visitors-rome_8348468001_20250403_151546.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   5%|▋              | 1135/24624 [00:14<04:30, 86.93file/s]2025-04-07 19:46:05,346 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_04_ap-top-stories-august-4-p_37307929_20250331_192056.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   5%|▋              | 1164/24624 [00:15<11:46, 33.19file/s]2025-04-07 19:46:06,297 - ERROR - Error processing downloaded_articles/www_usatoday_com_story_news_politics_2022_08_11_garland-doj-statement_10299617002_20250403_141117.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   5%|▋              | 1175/24624 [00:15<10:55, 35.80file/s]2025-04-07 19:46:06,507 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_world_2022_06_27_ukraine-shopping-mall-struck-russian-missile-several-dead_7750377001_20250331_140733.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   5%|▋              | 1186/24624 [00:15<08:39, 45.13file/s]2025-04-07 19:46:06,804 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_8360905001_20250403_154440.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   5%|▋              | 1194/24624 [00:16<08:55, 43.72file/s]2025-04-07 19:46:06,895 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_12_28_rescuers-use-kayaks-reach-pilot-after-crash_10958876002_20250407_123544.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   5%|▋              | 1215/24624 [00:16<06:21, 61.32file/s]2025-04-07 19:46:07,040 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_10554820002_20250401_185519.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:07,052 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_2022_08_14_suspect-who-stabbed-salman-rushdie-new-york-pleads-not-guilty_10322980002_20250331_182103.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   6%|▊              | 1365/24624 [00:17<04:11, 92.36file/s]2025-04-07 19:46:08,684 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_02_15_ukrainian-soldiers-freeze-sperm-ensure-legacy_11262079002_20250407_121247.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   6%|▊              | 1415/24624 [00:18<04:18, 89.63file/s]2025-04-07 19:46:09,240 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_04_new-citizens-take-oath-battleship-new-jersey_12206298002_20250403_114047.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   6%|▉              | 1437/24624 [00:18<04:00, 96.53file/s]2025-04-07 19:46:09,476 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_21_passengers-flee-burning-train-near-boston_10121111002_20250331_164215.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   6%|▉              | 1524/24624 [00:20<06:21, 60.53file/s]2025-04-07 19:46:11,376 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_8342500001_20250403_150648.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   6%|▉              | 1533/24624 [00:20<05:49, 66.01file/s]2025-04-07 19:46:11,695 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_11887073002_20250407_103630.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:11,695 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_08_23_inflation-reduces-access-indigenous-foods_7875298001_20250331_191854.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   6%|▉              | 1542/24624 [00:20<07:04, 54.36file/s]2025-04-07 19:46:11,786 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_17_california-town-hit-deadliest-wildfire-state-history-testing-new-warning-sirens_8359614001_20250403_154035.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   6%|▉              | 1552/24624 [00:21<06:06, 62.90file/s]2025-04-07 19:46:11,869 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_04_ap-top-stories-august-4-p_37307929_20250331_182914.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   6%|▉              | 1564/24624 [00:21<05:07, 74.89file/s]2025-04-07 19:46:11,925 - ERROR - Error processing downloaded_articles/uw-media_usatoday_com_embed_video_11703232002_20250402_115947.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   6%|▉              | 1585/24624 [00:21<04:33, 84.11file/s]2025-04-07 19:46:12,193 - ERROR - Error processing downloaded_articles/www_usatoday_com_story_sports_nhl_2022_08_27_nazem-kadri-brings-stanley-cup-to-hometown-mosque_50648473_20250403_115718.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   7%|█              | 1713/24624 [00:22<04:18, 88.78file/s]2025-04-07 19:46:13,649 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_04_ap-top-stories-august-4-p_37307929_20250331_190231.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:13,649 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_politics_2022_07_22_stand-trump-steve-bannon-found-guilty-contempt-defying-jan-6-panels-subpoena_10131618002_20250331_165344.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   7%|█              | 1745/24624 [00:23<03:57, 96.41file/s]2025-04-07 19:46:13,947 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_08_23_heavy-rainfall-causes-flooding-new-dallas-apartment-unit_7873414001_20250331_191735.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:13,980 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_11890278002_20250407_103104.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   7%|█              | 1779/24624 [00:23<03:50, 99.22file/s]2025-04-07 19:46:14,273 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_14_la-paz-bake-huge-cake-celebrate-revolution_12257175002_20250403_123331.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   7%|█             | 1790/24624 [00:23<03:46, 100.64file/s]2025-04-07 19:46:14,416 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_politics_2022_08_22_state-dept-concerned-dennis-rodman-trip-russia-griner_7870070001_20250331_191351.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   7%|█              | 1821/24624 [00:23<03:52, 97.87file/s]2025-04-07 19:46:15,781 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_politics_2022_11_09_best-yet-come-iowa-gov-kim-reynolds-says-during-reelection-acceptance-speech_8311525001_20250407_130357.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   8%|█▏             | 1851/24624 [00:25<09:39, 39.31file/s]2025-04-07 19:46:16,135 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_04_18_rats-trained-detect-trafficked-endangered-species_11686413002_20250402_114445.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   8%|█▏             | 1880/24624 [00:25<06:09, 61.48file/s]2025-04-07 19:46:16,426 - ERROR - Error processing downloaded_articles/www_usatoday_com_story_news_health_2022_04_27_std-rates-rising-testing-prevention_9539438002_20250331_160318.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   8%|█▏             | 1930/24624 [00:26<04:31, 83.73file/s]2025-04-07 19:46:16,923 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_22_georgia-abortion-center-grapples-ban_10126969002_20250331_165027.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   8%|█▏             | 1980/24624 [00:26<04:17, 87.91file/s]2025-04-07 19:46:17,502 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_03_20_tear-gas-fired-opposition-supporters-kenya_11507491002_20250405_131612.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   8%|█▏             | 2002/24624 [00:26<03:54, 96.64file/s]2025-04-07 19:46:17,687 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_14_ap-explains-man-charged-rape-girl-ohio_10062457002_20250331_155414.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:17,721 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_14_researchers-explore-alaskas-deep-sea_8350335001_20250403_152116.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   8%|█▎             | 2065/24624 [00:27<04:11, 89.80file/s]2025-04-07 19:46:18,406 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_07_today-history-august-8th_37357341_20250331_185042.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   9%|█▎             | 2096/24624 [00:27<04:05, 91.88file/s]2025-04-07 19:46:18,756 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_23_scholarships-aid-displaced-afghan-students_12284308002_20250403_131604.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:18,785 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_23_florida-annual-hemingway-look-alike-contest-begins_10135562002_20250331_165821.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   9%|█▎             | 2129/24624 [00:28<03:58, 94.50file/s]2025-04-07 19:46:19,051 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_8358927001_20250403_153951.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   9%|█▎             | 2170/24624 [00:28<03:57, 94.70file/s]2025-04-07 19:46:19,543 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_10_05_trial-underway-3-tied-gov-whitmer-plot_8190443001_20250331_210358.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   9%|█▎             | 2181/24624 [00:28<03:50, 97.16file/s]2025-04-07 19:46:19,599 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_entertainment_2023_03_30_white-house-gardens-show-signs-spring_11571167002_20250407_140054.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:19,649 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_21_string-quartet-brings-music-mississippi-inmates_10122281002_20250331_164241.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   9%|█▎             | 2191/24624 [00:28<03:55, 95.42file/s]2025-04-07 19:46:19,705 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_8360974001_20250403_154437.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:19,777 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_08_12_blaze-runs-through-big-island-amid-drought_10312243002_20250331_181515.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:   9%|█▍             | 2304/24624 [00:30<04:00, 92.63file/s]2025-04-07 19:46:20,953 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_08_11_beto-orourke-responds-heckler-expletive_10303524002_20250331_180956.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  10%|█▍             | 2440/24624 [00:33<05:50, 63.35file/s]2025-04-07 19:46:23,996 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_11_01_families-wounded-confront-parkland-shooter_8239198001_20250401_201834.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  10%|█▌             | 2498/24624 [00:33<04:15, 86.46file/s]2025-04-07 19:46:24,708 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_03_22_ap-top-stories-march-22-am_11520450002_20250405_134621.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  11%|█▌             | 2599/24624 [00:34<04:19, 85.01file/s]2025-04-07 19:46:25,815 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_02_22_nipsey-hussles-killer-sentenced_11320356002_20250407_121528.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  11%|█▌             | 2667/24624 [00:35<04:18, 84.98file/s]2025-04-07 19:46:26,551 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_19_thick-smoke-billows-wildfires-catalonia_10093950002_20250331_161954.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  11%|█▋             | 2688/24624 [00:35<03:59, 91.60file/s]2025-04-07 19:46:26,844 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_10_05_malfunctioning-skorean-missile-crashes-base_8184761001_20250331_205924.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  11%|█▋             | 2708/24624 [00:36<04:05, 89.28file/s]2025-04-07 19:46:27,076 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_24_us-and-south-korea-hold-urban-warfare-drill_8371349001_20250403_162122.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  11%|█▋             | 2747/24624 [00:36<04:11, 87.10file/s]2025-04-07 19:46:27,546 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_07_heavy-rain-and-strong-winds-lash-south-japan_8330059001_20250403_143752.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  11%|█▋             | 2818/24624 [00:37<03:45, 96.72file/s]2025-04-07 19:46:28,195 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_entertainment_2022_11_18_capitol-christmas-tree-arrives-north-carolina_10728247002_20250405_133839.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  12%|█▋             | 2848/24624 [00:37<04:02, 89.82file/s]2025-04-07 19:46:28,580 - ERROR - Error processing downloaded_articles/www_usatoday_com_story_tech_2022_07_06_amazon-prime-perks-grubhub_7808853001_20250331_144847.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  12%|█▊             | 2933/24624 [00:40<16:03, 22.52file/s]2025-04-07 19:46:31,121 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_21_progressive-outsider-wins-presidency-guatemala_8365724001_20250403_155942.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  12%|█▊             | 2954/24624 [00:40<09:43, 37.11file/s]2025-04-07 19:46:31,364 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_12204750002_20250403_113816.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  12%|█▊             | 3055/24624 [00:41<04:22, 82.07file/s]2025-04-07 19:46:32,515 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_17_un-grain-deal-ends-millions-pay-price_12266358002_20250403_124355.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  12%|█▊             | 3077/24624 [00:41<04:06, 87.35file/s]2025-04-07 19:46:32,772 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_04_26_ed-sheeran-testifies-court_11742044002_20250402_122448.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  13%|█▉             | 3087/24624 [00:42<03:59, 90.06file/s]2025-04-07 19:46:32,857 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_13_monsoon-season-swamps-new-dehli_12249283002_20250403_122407.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  13%|█▉             | 3107/24624 [00:42<04:04, 88.01file/s]2025-04-07 19:46:33,114 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_11772206002_20250402_124552.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  13%|█▉             | 3129/24624 [00:42<03:42, 96.68file/s]2025-04-07 19:46:33,340 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_19_jury-selection-underway-ex-trump-adviser_10092830002_20250331_161922.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  13%|█▉             | 3139/24624 [00:42<04:05, 87.67file/s]2025-04-07 19:46:33,474 - ERROR - Error processing downloaded_articles/volswire_usatoday_com_videos_news_politics_2022_10_25_florida-governor-debate-desantis-crist-make-their-arguments-crt_10592892002_20250401_191559.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  13%|█▉             | 3159/24624 [00:42<04:05, 87.37file/s]2025-04-07 19:46:33,734 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_06_30_peruvian-fishermen-celebrate-patron-saints-day_12190139002_20250403_112425.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  14%|██             | 3338/24624 [00:44<03:44, 94.71file/s]2025-04-07 19:46:35,669 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_11871190002_20250407_124056.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  14%|██             | 3359/24624 [00:45<03:35, 98.46file/s]2025-04-07 19:46:35,845 - ERROR - Error processing downloaded_articles/www_usatoday_com_story_sports_nba_mavericks_2023_05_04_luka-doncic-pay-funeral-costs-belgrade-school-shooting_70185511007_20250402_130137.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  14%|██             | 3369/24624 [00:45<03:50, 92.29file/s]2025-04-07 19:46:36,036 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_12171436002_20250403_110828.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  14%|██▏            | 3491/24624 [00:46<05:32, 63.57file/s]2025-04-07 19:46:37,491 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_politics_2022_07_08_biden-says-justice-department-review-death-former-japan-pm_10016229002_20250331_151112.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  14%|██▏            | 3513/24624 [00:46<04:22, 80.49file/s]2025-04-07 19:46:37,671 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_12308422002_20250403_140629.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:37,690 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_politics_2022_07_12_pat-cipollone-says-trump-wanted-voting-machines-seized_10040769002_20250331_153425.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  15%|██▏            | 3690/24624 [00:51<20:06, 17.36file/s]2025-04-07 19:46:41,956 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_04_27_south-korean-president-yoon-sings-american-pie_11750082002_20250402_123040.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  15%|██▎            | 3712/24624 [00:51<11:06, 31.39file/s]2025-04-07 19:46:42,092 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_02_27_ap-explains-supreme-court-student-loan-case_11360994002_20250407_123222.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  15%|██▎            | 3775/24624 [00:51<04:31, 76.86file/s]2025-04-07 19:46:42,831 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_05_03_ap-top-stories-may-3-p_11791376002_20250403_125922.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  15%|██▎            | 3796/24624 [00:52<04:00, 86.65file/s]2025-04-07 19:46:42,948 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_06_02_tropical-storm-mawar-brings-heavy-rains-okinawa_12018008002_20250405_130445.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  15%|██▎            | 3816/24624 [00:52<03:54, 88.86file/s]2025-04-07 19:46:43,187 - ERROR - Error processing downloaded_articles/www_usatoday_com_media_cinematic_video_38838525_fire-destroys-historic-upstate-new-york-church_20250403_145312.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  16%|██▎            | 3855/24624 [00:52<03:59, 86.82file/s]2025-04-07 19:46:43,679 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_8370905001_20250403_161744.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:43,710 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_03_15_ny-officials-take-down-gun-trafficking-ring_11480460002_20250404_174608.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  16%|██▍            | 3950/24624 [00:53<03:48, 90.53file/s]2025-04-07 19:46:44,630 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_10_04_california-braces-dry-year-drought-drags_8172594001_20250331_205111.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  16%|██▍            | 3991/24624 [00:54<03:55, 87.45file/s]2025-04-07 19:46:45,090 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_06_03_rescuers-work-non-stop-india-derailment-site_12026727002_20250407_130402.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  16%|██▍            | 4022/24624 [00:54<04:02, 85.07file/s]2025-04-07 19:46:45,435 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_01_oxford-high-school-shooter-feral-child_12308510002_20250403_140724.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  16%|██▍            | 4033/24624 [00:54<03:47, 90.51file/s]2025-04-07 19:46:45,589 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_04_21_thai-pm-plays-votes-park-kickabout_11710301002_20250402_120352.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  16%|██▍            | 4044/24624 [00:54<03:39, 93.64file/s]2025-04-07 19:46:45,725 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_29_tennessee-lawmakers-adjourn-tumultuous-session-accusations-shoving_8380817001_20250403_164822.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  16%|██▍            | 4055/24624 [00:54<03:32, 96.78file/s]2025-04-07 19:46:45,764 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_04_20_innocent-verdict-two-wrongly-convicted-men_11707990002_20250402_120323.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  17%|██▌            | 4210/24624 [00:56<03:36, 94.19file/s]2025-04-07 19:46:47,512 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_20_fans-react-spain-triumph-womens-world-cup-final_8365217001_20250403_155802.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  17%|██▌            | 4220/24624 [00:56<03:35, 94.77file/s]2025-04-07 19:46:47,626 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_09_27_hurricane-closes-tampa-airport-strands-visitors_10444510002_20250331_195304.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  17%|██▌            | 4250/24624 [00:57<03:39, 92.71file/s]2025-04-07 19:46:47,891 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_politics_2023_04_24_biden-tennessee-three-meet-white-house-following-expulsion-votes_11731114002_20250402_121736.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  17%|██▌            | 4300/24624 [00:57<03:32, 95.56file/s]2025-04-07 19:46:48,456 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_20_author-explores-70-us-cities-one-year_10105886002_20250331_163138.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  18%|██▋            | 4310/24624 [00:57<03:35, 94.31file/s]2025-04-07 19:46:48,527 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_03_03_need-lenten-fish-fry-pittsburgh-interactive-map-points-way_11388774002_20250404_175155.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  18%|██▋            | 4320/24624 [00:57<03:55, 86.37file/s]2025-04-07 19:46:48,709 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_03_29_kamala-harris-confronts-painful-past-ghana_11560376002_20250404_173445.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  18%|██▋            | 4349/24624 [00:58<03:53, 86.96file/s]2025-04-07 19:46:49,023 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_politics_2022_10_12_democrats-threaten-freeze-arms-sales-saudi-arabia_10477804002_20250401_152307.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  18%|██▋            | 4368/24624 [00:58<03:49, 88.31file/s]2025-04-07 19:46:49,212 - ERROR - Error processing downloaded_articles/admeter_usatoday_com_videos_news_politics_2023_04_20_white-house-dont-say-gay-bill-expansion-devastating-florida_11706080002_20250402_120233.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  18%|██▋            | 4451/24624 [00:59<03:47, 88.75file/s]2025-04-07 19:46:50,137 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_19_herzog-touts-israel-us-unbreakable-bond_12274419002_20250403_125633.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:50,190 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_04_13_interfaith-vigil-held-louisville-shooting-victims_11653749002_20250402_112251.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  18%|██▋            | 4462/24624 [00:59<03:37, 92.80file/s]2025-04-07 19:46:50,245 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_23_ap-top-stories-august-23_8369614001_20250407_103214.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:46:50,277 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_11026423002_20250405_134020.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  18%|██▋            | 4514/24624 [00:59<03:32, 94.84file/s]2025-04-07 19:46:50,774 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_05_08_protesters-gather-texas-capitol-decry-gun-violence_11825112002_20250404_174740.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  19%|██▊            | 4666/24624 [01:05<31:32, 10.55file/s]2025-04-07 19:46:56,188 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_01_20_ohio-officer-leave-after-punching-woman_11091827002_20250405_131745.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  19%|██▊            | 4675/24624 [01:05<23:32, 14.12file/s]2025-04-07 19:46:56,276 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_05_01_soccer-transforming-girls-lives-rio_11776728002_20250402_125135.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  19%|██▊            | 4716/24624 [01:05<08:11, 40.51file/s]2025-04-07 19:46:56,731 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_04_25_ap-top-stories-april-25th-am_11733305002_20250402_121835.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  19%|██▉            | 4796/24624 [01:06<05:12, 63.48file/s]2025-04-07 19:46:57,817 - ERROR - Error processing downloaded_articles/reviewed_usatoday_com_televisions_content_google-chromecast-google-tv-review-best-one-yet_20250331_170758.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  20%|██▉            | 4835/24624 [01:07<04:02, 81.72file/s]2025-04-07 19:46:58,290 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_03_trump-departs-washington-court-appearance_12314532002_20250403_142100.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  20%|██▉            | 4853/24624 [01:07<04:08, 79.45file/s]2025-04-07 19:46:58,498 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_10_03_zoo-succeeds-breeding-endangered-turtles_8169279001_20250331_204849.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  20%|██▉            | 4864/24624 [01:07<03:49, 86.15file/s]2025-04-07 19:46:58,523 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_03_27_minority-investors-struggle-faith-crypto_11548215002_20250407_102656.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  20%|███            | 4960/24624 [01:08<03:29, 93.70file/s]2025-04-07 19:46:59,672 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_21_northeast-floods-devastate-struggling-farmers_12279256002_20250403_130519.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  20%|███            | 4993/24624 [01:09<03:36, 90.55file/s]2025-04-07 19:46:59,965 - ERROR - Error processing downloaded_articles/www_usatoday_com_story_money_personalfinance_2022_07_15_wells-fargo-citi-jpm-earnings-recession_10060859002_20250331_160236.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  20%|███            | 5003/24624 [01:09<05:10, 63.15file/s]2025-04-07 19:47:00,333 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_19_ap-minuteworld-july-19-5-p_12275134002_20250403_125733.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  20%|███            | 5025/24624 [01:09<04:08, 78.89file/s]2025-04-07 19:47:00,548 - ERROR - Error processing downloaded_articles/www_usatoday_com_story_news_politics_elections_2022_11_02_elissa-slotkin-tom-barrett-in-one-of-most-expensive-us-house-races_69610762007_20250331_195112.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  20%|███            | 5036/24624 [01:09<03:47, 85.98file/s]2025-04-07 19:47:00,558 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_07_rahul-gandhi-reinstated-lawmaker-india_8329832001_20250403_143704.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  21%|███            | 5093/24624 [01:10<04:57, 65.73file/s]2025-04-07 19:47:01,477 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_25_anger-myanmar-executes-four-political-prisoners_10142691002_20250331_170533.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  21%|███            | 5104/24624 [01:10<04:19, 75.33file/s]2025-04-07 19:47:01,572 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_08_11_sharpton-demands-answers-womans-funeral_10300988002_20250331_180826.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  21%|███            | 5123/24624 [01:10<04:08, 78.56file/s]2025-04-07 19:47:01,780 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_05_05_ap-top-stories-may-5_11802236002_20250405_125608.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  21%|███▏           | 5145/24624 [01:11<03:34, 90.81file/s]2025-04-07 19:47:01,953 - ERROR - Error processing downloaded_articles/badgerswire_usatoday_com_videos_news_nation_2022_10_13_vpc-parkland-shparkland-school-shooter-nikolas-cruz-gets-life-without-parole-jury-declines-death-pen_10486859002_20250401_152925.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  21%|███▏           | 5242/24624 [01:12<03:44, 86.24file/s]2025-04-07 19:47:03,146 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_09_28_wh-struggles-explain-biden-gaffe-over-late-rep_10454234002_20250331_195946.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:47:03,203 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_07_today-history-august-8th_37357341_20250331_183733.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  22%|███▏           | 5325/24624 [01:13<03:25, 94.12file/s]2025-04-07 19:47:04,037 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_03_ap-top-stories-july-2-p_7797866001_20250331_142312.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  22%|███▎           | 5365/24624 [01:13<03:31, 90.92file/s]2025-04-07 19:47:04,450 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_02_18_grassroots-groups-baltics-strive-help-ukraine_11289306002_20250405_130449.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  22%|███▎           | 5438/24624 [01:14<03:22, 94.95file/s]2025-04-07 19:47:05,273 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_12252801002_20250403_122314.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  22%|███▎           | 5488/24624 [01:14<03:29, 91.38file/s]2025-04-07 19:47:05,859 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_17_intense-fighting-continues-along-northeast-frontline-ukraine_8359657001_20250403_154104.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  23%|███▍           | 5546/24624 [01:15<03:57, 80.48file/s]2025-04-07 19:47:06,480 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_08_friends-and-families-pay-tribute-oshae-sibley_8335129001_20250403_144832.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  23%|███▍           | 5555/24624 [01:15<04:58, 63.96file/s]2025-04-07 19:47:06,759 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_02_20_4-dead-including-gunman-texas-shooting_11306217002_20250405_125135.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  23%|███▍           | 5593/24624 [01:16<05:02, 62.91file/s]2025-04-07 19:47:07,299 - ERROR - Error processing downloaded_articles/admeter_usatoday_com_videos_news_politics_2023_08_01_trump-indicted-conduct-before-during-and-after-his-presidency_12308734002_20250403_140818.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  23%|███▍           | 5630/24624 [01:16<03:53, 81.22file/s]2025-04-07 19:47:07,663 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_15_ap-top-stories-july-15-p_12260312002_20250403_123408.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  23%|███▍           | 5697/24624 [01:17<03:45, 83.95file/s]2025-04-07 19:47:08,479 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_09_27_rare-cloned-horse-learns-ways-wild-zoo_10445022002_20250331_195341.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  23%|███▌           | 5756/24624 [01:18<03:56, 79.71file/s]2025-04-07 19:47:09,274 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_06_texas-officials-arrest-suspect-deadly-18-arson_12218310002_20250403_115051.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  23%|███▌           | 5767/24624 [01:18<03:41, 85.24file/s]2025-04-07 19:47:09,351 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_21_suspected-palestinian-gunman-kills-israeli-wounds-another-latest-attack-occupied-west-bank_8366252001_20250403_160210.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:47:09,362 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_12205805002_20250403_113936.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  24%|███▌           | 5825/24624 [01:24<12:16, 25.53file/s]2025-04-07 19:47:15,311 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_06_22_restaurant-gas-explosion-kills-dozens-china_12146004002_20250403_104639.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  24%|███▌           | 5912/24624 [01:25<03:43, 83.54file/s]2025-04-07 19:47:16,284 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_28_search-ongoing-deadly-philippines-ferry-capsize_12298452002_20250403_134613.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  24%|███▋           | 5961/24624 [01:26<03:55, 79.31file/s]2025-04-07 19:47:16,926 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_05_03_ap-top-stories-may-3-p_11791376002_20250403_125851.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  24%|███▋           | 5987/24624 [01:26<05:32, 56.00file/s]2025-04-07 19:47:17,323 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_02_02_congolese-welcome-pope-francis-ndolo-airport_11166704002_20250404_174521.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  24%|███▋           | 6020/24624 [01:26<03:47, 81.68file/s]2025-04-07 19:47:17,649 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_03_wait-us-passports-snarls-summer-plans_12201715002_20250403_113505.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:47:17,659 - ERROR - Error processing downloaded_articles/www_usatoday_com_story_tech_2022_12_08_ramesh-sunny-balwani-sentence-elizabeth-holmes_10857577002_20250407_122803.html: 'dict' object has no attribute 'get_text'
# ...
# 2025-04-07 19:54:08,774 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_23_ap-top-stories-august-23_8369614001_20250403_143928.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  93%|█████████████ | 22866/24624 [08:18<00:19, 89.51file/s]2025-04-07 19:54:09,260 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_12_28_bats-plunged-ground-cold-released_10962026002_20250405_131402.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  93%|█████████████ | 22897/24624 [08:18<00:18, 92.16file/s]2025-04-07 19:54:09,613 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_07_today-history-august-8th_37357341_20250331_174605.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  93%|█████████████ | 22928/24624 [08:19<00:19, 88.26file/s]2025-04-07 19:54:09,879 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2020_09_17_ap-top-stories-september-17_3477545001_20250331_194449.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  93%|█████████████ | 22938/24624 [08:19<00:18, 90.33file/s]2025-04-07 19:54:10,044 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_04_ap-top-stories-august-4-p_37307929_20250331_182018.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  93%|█████████████ | 22989/24624 [08:19<00:19, 84.39file/s]2025-04-07 19:54:10,655 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_05_17_biden-scraps-visit-papua-new-guinea-australia_11886864002_20250404_174731.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  93%|█████████████ | 23000/24624 [08:19<00:18, 89.15file/s]2025-04-07 19:54:10,679 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_10729317002_20250405_130242.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  93%|█████████████ | 23011/24624 [08:19<00:17, 93.30file/s]2025-04-07 19:54:10,878 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_05_24_aerial-video-shows-school-bus-fire-nyc_11943786002_20250407_104602.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  94%|█████████████ | 23068/24624 [08:20<00:17, 86.99file/s]2025-04-07 19:54:11,463 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_23_missouri-schools-struggle-late-summer-heat-wave_8370988001_20250403_161800.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  94%|█████████████ | 23079/24624 [08:20<00:16, 93.02file/s]2025-04-07 19:54:11,582 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_06_28_medieval-spanish-city-swelters-hot-spell_12176644002_20250403_111309.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:54:11,621 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_06_24_harris-pledges-protect-abortion-rights_12160796002_20250403_105820.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  94%|█████████████▏| 23252/24624 [08:22<00:15, 88.56file/s]2025-04-07 19:54:13,628 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_01_mayor-ukraine-city-braces-russian-advance_7785374001_20250331_141439.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  94%|█████████████▏| 23262/24624 [08:22<00:14, 91.30file/s]2025-04-07 19:54:13,730 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_12278087002_20250403_130350.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  95%|█████████████▏| 23290/24624 [08:23<00:15, 85.01file/s]2025-04-07 19:54:14,131 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_12_12_ohio-exhibit-honors-oldest-former-us-treasurer_10881563002_20250407_121823.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  95%|█████████████▎| 23331/24624 [08:23<00:14, 88.16file/s]2025-04-07 19:54:14,592 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_05_03_ap-top-stories-may-3-p_11791376002_20250403_125916.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  95%|█████████████▎| 23460/24624 [08:25<00:13, 86.86file/s]2025-04-07 19:54:16,004 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_23_ap-top-stories-august-23_8369614001_20250405_124151.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:54:16,073 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_05_01_biden-vows-banking-system-safe-and-sound_11777146002_20250402_125154.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:54:16,086 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_04_ap-top-stories-august-4-p_37307929_20250331_184416.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  95%|█████████████▎| 23472/24624 [08:25<00:12, 95.70file/s]2025-04-07 19:54:16,236 - ERROR - Error processing downloaded_articles/www_usatoday_com_news-sitemap.xml_20250401_201200.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  95%|█████████████▎| 23510/24624 [08:25<00:13, 80.66file/s]2025-04-07 19:54:16,657 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_11_jury-handwritten-document-found-aretha-franklins-couch-valid_12239151002_20250403_121244.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  96%|█████████████▍| 23570/24624 [08:26<00:12, 85.16file/s]2025-04-07 19:54:17,428 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_politics_2022_07_10_afghan-refugees-torn-between-new-lives-us-and-haunting-realities-home_10018674002_20250331_151738.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  96%|█████████████▍| 23600/24624 [08:26<00:11, 87.26file/s]2025-04-07 19:54:17,708 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2020_09_17_ap-top-stories-september-17_3477545001_20250331_202739.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  96%|█████████████▍| 23645/24624 [08:27<00:11, 82.99file/s]2025-04-07 19:54:18,316 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_07_firefighters-tackle-wildfires-portugal-and-spain_8329615001_20250403_143625.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  96%|█████████████▌| 23753/24624 [08:28<00:10, 82.90file/s]2025-04-07 19:54:19,704 - ERROR - Error processing downloaded_articles/www_usatoday_com_news-sitemap.xml_20250403_160441.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  97%|█████████████▌| 23772/24624 [08:29<00:11, 75.98file/s]2025-04-07 19:54:19,898 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_11696194002_20250402_115534.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:54:19,910 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2020_04_29_ap-top-stories-april-29-p_649161000_20250407_103205.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:54:19,957 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_07_today-history-august-8th_37357341_20250331_190218.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  97%|█████████████▌| 23825/24624 [08:29<00:08, 93.64file/s]2025-04-07 19:54:20,487 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_05_27_sloth-bear-cubs-make-public-debut-philadelphia-zoo_11974823002_20250407_122054.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  97%|█████████████▌| 23856/24624 [08:29<00:07, 96.76file/s]2025-04-07 19:54:20,727 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_10_03_nobel-win-unlocking-secrets-ancient-dna_8169797001_20250331_204936.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:54:20,738 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_23_ap-top-stories-august-23_8369614001_20250403_160706.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  97%|█████████████▌| 23896/24624 [08:30<00:08, 85.46file/s]2025-04-07 19:54:21,207 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_04_ap-top-stories-august-4-p_37307929_20250407_104158.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:54:21,242 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_10_04_frustration-and-desperation-ians-effects-linger_8172533001_20250331_205113.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:54:21,243 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_8365735001_20250403_155935.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  97%|█████████████▌| 23908/24624 [08:30<00:07, 94.05file/s]2025-04-07 19:54:21,393 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_05_02_portuguese-police-make-major-drug-bust_11782469002_20250402_125756.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  98%|█████████████▋| 24016/24624 [08:31<00:09, 64.51file/s]2025-04-07 19:54:22,776 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_12221106002_20250403_115312.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:54:22,845 - ERROR - Error processing downloaded_articles/www_usatoday_com_embed_video_8377842001_20250403_163749.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  98%|█████████████▋| 24049/24624 [08:32<00:07, 72.13file/s]2025-04-07 19:54:23,338 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_10_28_uvalde-families-push-shakeup-election-day_10628454002_20250401_195917.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  98%|█████████████▋| 24104/24624 [08:33<00:08, 63.27file/s]2025-04-07 19:54:24,125 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_02_witness-describes-impact-missile-strike-serhiivka_7795714001_20250331_142233.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  98%|█████████████▋| 24130/24624 [08:33<00:06, 73.11file/s]2025-04-07 19:54:24,380 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_06_first-giant-panda-born-taiwan-turns-10_12216302002_20250403_114900.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  98%|█████████████▋| 24139/24624 [08:33<00:06, 77.05file/s]2025-04-07 19:54:24,515 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_10_10_bernanke-nobel-prize-completely-unexpected_10461295002_20250331_212725.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  98%|█████████████▋| 24167/24624 [08:34<00:05, 80.66file/s]2025-04-07 19:54:24,893 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_07_11_rare-fossils-go-up-auction_12236174002_20250403_121047.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  98%|█████████████▊| 24228/24624 [08:34<00:05, 71.68file/s]2025-04-07 19:54:25,711 - ERROR - Error processing downloaded_articles/golfweek_usatoday_com_videos_news_politics_2022_07_08_president-biden-signs-executive-order-protect-abortion-access_10016021002_20250331_151102.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  99%|█████████████▊| 24258/24624 [08:35<00:04, 82.36file/s]2025-04-07 19:54:25,990 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_07_27_ar-15-style-guns-have-brought-over-1-billion_10167441002_20250331_172705.html: 'dict' object has no attribute 'get_text'
# 2025-04-07 19:54:25,990 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_10_27_tourism-boom-helps-greece-face-rising-costs_10616591002_20250401_193643.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  99%|█████████████▊| 24269/24624 [08:35<00:04, 88.26file/s]2025-04-07 19:54:26,157 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2018_08_07_today-history-august-8th_37357341_20250331_192136.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  99%|█████████████▊| 24290/24624 [08:35<00:03, 90.75file/s]2025-04-07 19:54:26,295 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2024_01_25_ap-top-stories-january-25-a_72349433007_20250407_104102.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  99%|█████████████▊| 24301/24624 [08:35<00:03, 93.48file/s]2025-04-07 19:54:26,454 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_08_02_european-evacuees-niger-arrive-france_12309428002_20250403_140928.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  99%|█████████████▊| 24339/24624 [08:36<00:03, 77.36file/s]2025-04-07 19:54:26,978 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2023_06_28_brushfire-prompts-evacuations-scottsdale-arizona_12176564002_20250403_111229.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  99%|█████████████▉| 24416/24624 [08:37<00:02, 82.28file/s]2025-04-07 19:54:27,918 - ERROR - Error processing downloaded_articles/www_usatoday_com_story_opinion_voices_2022_10_25_why-gen-z-should-vote-midterm-elections_10535049002_20250401_191627.html: 'dict' object has no attribute 'get_text'
# Extracting Articles:  99%|█████████████▉| 24495/24624 [08:37<00:01, 86.17file/s]2025-04-07 19:54:28,733 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2022_10_13_republicans-try-expand-gains-latino-voters_10485558002_20250401_152824.html: 'dict' object has no attribute 'get_text'
# Extracting Articles: 100%|█████████████▉| 24534/24624 [08:38<00:01, 89.65file/s]2025-04-07 19:54:29,196 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_nation_2019_12_23_today-history-december-23rd_2731555001_20250404_175103.html: 'dict' object has no attribute 'get_text'
# Extracting Articles: 100%|█████████████▉| 24545/24624 [08:38<00:00, 94.37file/s]2025-04-07 19:54:29,345 - ERROR - Error processing downloaded_articles/eu_usatoday_com_storytelling_grid_women-of-the-year-2023_20250407_101748.html: 'dict' object has no attribute 'get_text'
# Extracting Articles: 100%|█████████████▉| 24585/24624 [08:38<00:00, 88.32file/s]2025-04-07 19:54:29,811 - ERROR - Error processing downloaded_articles/www_usatoday_com_videos_news_politics_2023_08_09_biden-touts-clean-energy-wind-tower-facility-groundbreaking-event_8338215001_20250403_145705.html: 'dict' object has no attribute 'get_text'
# Extracting Articles: 100%|█████████████▉| 24616/24624 [08:39<00:00, 87.77file/s]2025-04-07 19:54:30,139 - ERROR - Error processing downloaded_articles/www_usatoday_com_story_money_2022_10_10_nobel-prize-economics-ben-bernanke-bank-research_8233145001_20250331_212637.html: 'dict' object has no attribute 'get_text'
# Extracting Articles: 100%|██████████████| 24624/24624 [08:39<00:00, 47.41file/s]
# 2025-04-07 19:54:46,777 - INFO - Extracted 23963 articles to usa_today_articles.csv
# 2025-04-07 19:54:46,781 - INFO - Skipped 661 files due to errors or empty content
